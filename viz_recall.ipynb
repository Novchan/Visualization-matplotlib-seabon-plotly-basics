# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

seattle_weather = pd.read_csv('seattle_weather.csv')
austin_weather = pd.read_csv('austin_weather.csv')

con = {1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',7:'Jul',8:'Aug',9:'Sep',10:'Oct',11:'Nov',12:'Dec'}
sor = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

austin_weather['MONTH'] = austin_weather.DATE.map(lambda x: con[x])

seattle_weather['MONTH'] = seattle_weather.DATE.map(lambda x: con[x])

# %%
seattle_weather_agg = seattle_weather.groupby('MONTH',as_index=False).agg(np.mean)

# %%
seattle_weather_agg.sort_values(by='DATE',inplace=True)

# %%
seattle_weather_agg
# Out:
#    MONTH  DATE  MLY-CLDD-BASE45  MLY-CLDD-BASE50  MLY-CLDD-BASE55  \
# 4    Jan   1.0        24.466667      -515.133333     -6221.466667
# 3    Feb   2.0        27.866667         3.466667     -7258.466667
# 7    Mar   3.0        74.800000        17.333333      -516.400000
# 0    Apr   4.0       155.466667        58.000000        14.933333
# 8    May   5.0       318.133333       176.333333        72.666667
# 6    Jun   6.0       452.866667       304.266667       165.800000
# 5    Jul   7.0       611.266667       456.333333       302.800000
# 1    Aug   8.0       623.266667       468.266667       314.133333
# 11   Sep   9.0       451.000000       302.666667       165.466667
# 10   Oct  10.0       218.733333        96.933333        26.200000
# 9    Nov  11.0        62.600000        14.266667     -1035.533333
# 2    Dec  12.0        14.600000     -1554.000000     -5703.133333
#
#     MLY-CLDD-BASE57  MLY-CLDD-BASE60  MLY-CLDD-BASE70  MLY-CLDD-BASE72  \
# ...

# %%
climate_chg = pd.read_csv('climate_change.csv',parse_dates=['date'],index_col=['date'])

# %%
medals = pd.read_csv('medals_by_country_2016.csv',index_col=0)  #<-setting the first col as index

summer = pd.read_csv('summer2016.csv')

# %%
import matplotlib.pyplot as plt

# %%
fig,ax = plt.subplots()

## If use below code, then sth strang when ax.set_title etc
# ax = plt.plot(seattle_weather_agg["MONTH"],seattle_weather_agg["MLY-PRCP-NORMAL"],marker='o',color='red',linestyle='--')
# ax = plt.plot(austin_weather["MONTH"],austin_weather["MLY-PRCP-NORMAL"],marker='v',linestyle='--')

ax.plot(seattle_weather_agg["MONTH"],seattle_weather_agg["MLY-PRCP-NORMAL"],marker='o',color='red',linestyle='--')
ax.plot(austin_weather["MONTH"],austin_weather["MLY-PRCP-NORMAL"],marker='v',linestyle='--')

ax.annotate('boom',xy=['Nov',8],xytext=['Aug',5],arrowprops={"arrowstyle":'->',"color":'r'})


ax.set_title("Temperature chart")
ax.set_xlabel("Month")
ax.set_ylabel("participation")
# Out:
# Text(0, 0.5, 'participation')

# %%
seattle_weather_agg.head()
# Out:
#   MONTH  DATE  MLY-CLDD-BASE45  MLY-CLDD-BASE50  MLY-CLDD-BASE55  \
# 4   Jan   1.0        24.466667      -515.133333     -6221.466667
# 3   Feb   2.0        27.866667         3.466667     -7258.466667
# 7   Mar   3.0        74.800000        17.333333      -516.400000
# 0   Apr   4.0       155.466667        58.000000        14.933333
# 8   May   5.0       318.133333       176.333333        72.666667
#
#    MLY-CLDD-BASE57  MLY-CLDD-BASE60  MLY-CLDD-BASE70  MLY-CLDD-BASE72  \
# 4     -3629.266667      -518.466667         0.000000              0.0
# 3     -6740.066667     -1036.933333         0.000000              0.0
# 7     -3110.200000     -7777.000000         0.000000              0.0
# 0         7.866667         2.400000     -1555.400000              0.0
# 8        46.200000        21.133333     -4147.266667          -7777.0
#
#    MLY-CLDD-NORMAL  ...  MLY-TMIN-AVGNDS-LSTH060  MLY-TMIN-AVGNDS-LSTH070  \
# 4         0.000000  ...               310.000000                    310.0
# ...

# %%
fig,ax = plt.subplots(2,2)

#MLY-PRCP-NORMAL

ax[0,0].plot(seattle_weather_agg["MONTH"],seattle_weather_agg["MLY-PRCP-NORMAL"],marker='o',color='red',linestyle='--')
ax[0,1].plot(seattle_weather_agg["MONTH"],seattle_weather_agg["MLY-TAVG-NORMAL"],marker='o',color='red',linestyle='--')
ax[1,0].plot(austin_weather["MONTH"],austin_weather["MLY-PRCP-NORMAL"])

# plt.set_title("multi-graph")  not correct

# ax.set_title wont work here
plt.suptitle("test")
# Out:
# Text(0.5, 0.98, 'test')

# %%
fig,ax= plt.subplots(2,1,sharex=True)

ax[0].plot(seattle_weather_agg["MONTH"],seattle_weather_agg["MLY-PRCP-NORMAL"],marker='o',color='red',linestyle='--')

# ax.set_title wont work here
plt.suptitle("test")
# Out:
# Text(0.5, 0.98, 'test')

# %%
climate_chg.head()
# Out:
#                co2  relative_temp
# date
# 1958-03-06  315.71           0.10
# 1958-04-06  317.45           0.01
# 1958-05-06  317.50           0.08
# 1958-06-06     NaN          -0.05
# 1958-07-06  315.86           0.06

# %%
climate_sliced = climate_chg['1970-01-01':'1979-12-31']

fig,ax = plt.subplots()

ax.plot(climate_chg.index,climate_chg["co2"])

ax2 = ax.twinx()  #<-in order to have double y axis
ax2.plot(climate_chg.index,climate_chg["relative_temp"],color='r')

ax.set_xlabel('year')
ax.set_title("the")
# Out:
# Text(0.5, 1.0, 'the')

# %%
medal = pd.read_csv("medals_by_country_2016.csv")
# medal.rename(columns={"":"Country"})
medal.columns = ['Country', 'Bronze', 'Gold', 'Silver']

medal
# Out:
#          Country  Bronze  Gold  Silver
# 0  United States      67   137      52
# 1        Germany      67    47      43
# 2  Great Britain      26    64      55
# 3         Russia      35    50      28
# 4          China      35    44      30
# 5         France      21    20      55
# 6      Australia      25    23      34
# 7          Italy      24     8      38
# 8         Canada      61     4       4
# 9          Japan      34    17      13

# %%
fig,ax = plt.subplots()

ax.bar(medal.Country,medal.Bronze,color='y',label="Bronze")
ax.bar(medal.Country,medal.Silver,color='b',bottom=medal.Bronze,label="Silver")
ax.bar(medal.Country,medal.Gold,color='r',bottom=medal.Silver + medal.Bronze,label="Gold")

ax.legend()  #<- to shows the labels
ax.set_xlabel("Country")
ax.set_xticklabels(medal.Country,rotation=90)

# ax.bar(medal.Country,medal.Gold)
# Out:
# /var/folders/k2/0zwyn2913cvf5k4bldh_v2540000gn/T/ipykernel_10724/1917725756.py:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(medal.Country,rotation=90)
# [Text(0, 0, 'United States'),
#  Text(1, 0, 'Germany'),
#  Text(2, 0, 'Great Britain'),
#  Text(3, 0, 'Russia'),
#  Text(4, 0, 'China'),
#  Text(5, 0, 'France'),
#  Text(6, 0, 'Australia'),
#  Text(7, 0, 'Italy'),
#  Text(8, 0, 'Canada'),
#  Text(9, 0, 'Japan')]

# %%
summer = pd.read_csv('summer2016.csv')
summer.head()

summer_row = summer[summer['Sport']=='Rowing']

# %%
summer_gym = summer[summer.Sport=='Gymnastics']

# %%
summer_gym.head()
# Out:
#      Unnamed: 0    ID                         Name Sex   Age  Height  Weight  \
# 4           794   455  Denis Mikhaylovich Ablyazin   M  24.0   161.0    62.0
# 5           796   455  Denis Mikhaylovich Ablyazin   M  24.0   161.0    62.0
# 6           797   455  Denis Mikhaylovich Ablyazin   M  24.0   161.0    62.0
# 122       18577  9829   David Sagitovich Belyavsky   M  24.0   165.0    55.0
# 123       18579  9829   David Sagitovich Belyavsky   M  24.0   165.0    55.0
#
#        Team  NOC        Games  Year  Season            City       Sport  \
# 4    Russia  RUS  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
# 5    Russia  RUS  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
# 6    Russia  RUS  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
# 122  Russia  RUS  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
# 123  Russia  RUS  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
#
#                                 Event   Medal
# ...

# %%
fig,ax = plt.subplots()

ax.hist(summer_row.Weight,bins=5,histtype='step',color='r',label='Rowing')
ax.hist(summer_gym.Weight,bins=5,color='b',histtype='step',label='Gym')


ax.legend(loc="center")
ax.set_xlabel("Weight(kg)")
# Out:
# Text(0.5, 0, 'Weight(kg)')
